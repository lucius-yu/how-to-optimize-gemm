# %% [markdown]
# # Computing a 4 x 4 block of C at a time
#
# We now compute a 4 x 4 block of C at a time in order to use vector instructions and vector registers effectively.
#
# The idea is as follows: There are special instructions as part of the SSE3 instruction set that allow one to perform two 'multiply accumulate' operations (two multiplies and two adds) per clock cycle for a total of four floating point operations per clock cycle. To use these, one has to place data in 'vector registers'. There are sixteen of these, each of which can hold two double precision numbers. So, we can keep 32 double precision numbers in registers. We will use sixteen of these to hold elements of C, a 4 x 4 block.
#
#
# * SSE stands for Streaming SIMD Extensions, It is an instruction set extension to x*6 architecture, designed by Intel and introduced in 1999 in their Pentium III.
# * SIMD stands for Single instruction, Multiple data (SIMD). SIMD instructions can greatly increase performance when exactly the same operations are to be performed on multiple data objects. Typical applications are digital signal processing and graphics processing.
# * SSE was subsequently expanded by Intel to SSE2, SSE3, SSSE3 and SSE4.

# %%
# set environment 
# %env ROOT_PATH=../..
# Out:
# env: ROOT_PATH=../..

# %%
# load libs
from load_data import load_data

# path
root_path='../..'

# %% [markdown]
# ## MMult_4x4_3.c
#
# We will setup a function AddDot4x4 to update a 4x4 block of Matrix C. So we will update 16 elements in Matrix C.
# * Remember for each element update, we need to calucate the dot-product of *ith* row of matrix A and *jth* column of matrix B.
# * The dot-product will have k multiplication and updates because matrix A is m x k and matrix B is k x n
#
# AddDot4x4
# * Call 16 times function AddDot
#
# ```
# void AddDot4x4( int k, double *a, int lda,  double *b, int ldb, double *c, int ldc )
# {
#   /* So, this routine computes a 4x4 block of matrix A
#
#            C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 ).
#            C( 1, 0 ), C( 1, 1 ), C( 1, 2 ), C( 1, 3 ).
#            C( 2, 0 ), C( 2, 1 ), C( 2, 2 ), C( 2, 3 ).
#            C( 3, 0 ), C( 3, 1 ), C( 3, 2 ), C( 3, 3 ).
#
#      Notice that this routine is called with c = C( i, j ) in the
#      previous routine, so these are actually the elements
#
#            C( i  , j ), C( i  , j+1 ), C( i  , j+2 ), C( i  , j+3 )
#            C( i+1, j ), C( i+1, j+1 ), C( i+1, j+2 ), C( i+1, j+3 )
#            C( i+2, j ), C( i+2, j+1 ), C( i+2, j+2 ), C( i+2, j+3 )
#            C( i+3, j ), C( i+3, j+1 ), C( i+3, j+2 ), C( i+3, j+3 )
#
#      in the original matrix C */
#
#   /* First row */
#   AddDot( k, &A( 0, 0 ), lda, &B( 0, 0 ), &C( 0, 0 ) );
#   AddDot( k, &A( 0, 0 ), lda, &B( 0, 1 ), &C( 0, 1 ) );
#   AddDot( k, &A( 0, 0 ), lda, &B( 0, 2 ), &C( 0, 2 ) );
#   AddDot( k, &A( 0, 0 ), lda, &B( 0, 3 ), &C( 0, 3 ) );
#
#   /* Second row */
#   AddDot( k, &A( 1, 0 ), lda, &B( 0, 0 ), &C( 1, 0 ) );
#   AddDot( k, &A( 1, 0 ), lda, &B( 0, 1 ), &C( 1, 1 ) );
#   AddDot( k, &A( 1, 0 ), lda, &B( 0, 2 ), &C( 1, 2 ) );
#   AddDot( k, &A( 1, 0 ), lda, &B( 0, 3 ), &C( 1, 3 ) );
#
#   /* Third row */
#   AddDot( k, &A( 2, 0 ), lda, &B( 0, 0 ), &C( 2, 0 ) );
#   AddDot( k, &A( 2, 0 ), lda, &B( 0, 1 ), &C( 2, 1 ) );
#   AddDot( k, &A( 2, 0 ), lda, &B( 0, 2 ), &C( 2, 2 ) );
#   AddDot( k, &A( 2, 0 ), lda, &B( 0, 3 ), &C( 2, 3 ) );
#
#   /* Four row */
#   AddDot( k, &A( 3, 0 ), lda, &B( 0, 0 ), &C( 3, 0 ) );
#   AddDot( k, &A( 3, 0 ), lda, &B( 0, 1 ), &C( 3, 1 ) );
#   AddDot( k, &A( 3, 0 ), lda, &B( 0, 2 ), &C( 3, 2 ) );
#   AddDot( k, &A( 3, 0 ), lda, &B( 0, 3 ), &C( 3, 3 ) );
# }
# ```
# AddDot
# * Dot product, k times multiplication, addition and assignments
#
# ```
# /* Create macro to let X( i ) equal the ith element of x */
#
# #define X(i) x[ (i)*incx ]
#
# void AddDot( int k, double *x, int incx,  double *y, double *gamma )
# {
#   /* compute gamma := x' * y + gamma with vectors x and y of length n.
#
#      Here x starts at location x with increment (stride) incx and y starts at location y and has (implicit) stride of 1.
#   */
#
#   int p;
#
#   for ( p=0; p<k; p++ ){
#     *gamma += X( p ) * y[ p ];
#   }
# }
# ```

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_3 -DOUT=../data/MMult_4x4_3 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_3.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_3.c.o   -c /root/src/MMult_4x4_3.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_3.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    9.22 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   9.22 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult2.csv', f'{root_path}/data/MMult_4x4_3.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# No performance gain at this point

# %% [markdown]
# ## MMult_4x4_4.c
#
# We just remove the funtion AddDot and "inline" AddDot operation in AddDot4x4. I suppose it will not give performance gain

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_4 -DOUT=../data/MMult_4x4_4 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_4.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_4.c.o   -c /root/src/MMult_4x4_4.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_4.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    9.25 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   9.26 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_3.csv', f'{root_path}/data/MMult_4x4_4.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ## MMult_4x4_5.c
#
# In this version, we merge each set of four loops, computing four inner products simultaneously. Note:
#
# * In previous version, we use 16 for-loops to calculate 16 dot-products.
# * In this version, only 1 for-loop to calculate 16 dot-products. Then we start to get performance benefit from blocking, i.e. fuse 16 loops into 1 loop
#
# ```
#     /* First row */
#     //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 0 ), &C( 0, 0 ) );
#     for ( p=0; p<k; p++ ){
#         C( 0, 0 ) += A( 0, p ) * B( p, 0 );
#         C( 0, 1 ) += A( 0, p ) * B( p, 1 );
#         C( 0, 2 ) += A( 0, p ) * B( p, 2 );
#         C( 0, 3 ) += A( 0, p ) * B( p, 3 );
#
#         /* Second row */
#         C( 1, 0 ) += A( 1, p ) * B( p, 0 );
#         C( 1, 1 ) += A( 1, p ) * B( p, 1 );
#         C( 1, 2 ) += A( 1, p ) * B( p, 2 );
#         C( 1, 3 ) += A( 1, p ) * B( p, 3 );
#
#         /* Third row */
#         C( 2, 0 ) += A( 2, p ) * B( p, 0 );
#         C( 2, 1 ) += A( 2, p ) * B( p, 1 );
#         C( 2, 2 ) += A( 2, p ) * B( p, 2 );
#         C( 2, 3 ) += A( 2, p ) * B( p, 3 );
#
#         /* Fourth row */
#         C( 3, 0 ) += A( 3, p ) * B( p, 0 );
#         C( 3, 1 ) += A( 3, p ) * B( p, 1 );
#         C( 3, 2 ) += A( 3, p ) * B( p, 2 );
#         C( 3, 3 ) += A( 3, p ) * B( p, 3 );
#     }
# ```

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_5 -DOUT=../data/MMult_4x4_5 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_5.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_5.c.o   -c /root/src/MMult_4x4_5.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_5.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    8.46 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   8.46 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_4.csv', f'{root_path}/data/MMult_4x4_5.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# We get performance gain from blocking

# %% [markdown]
# ## MMult_4x4_6.c
#
# In this version, We accumulate the elements of C in registers and use a register for elements of A. i.e.
# * use register to gain performance
# * use 4x4 block to gain performance by fusing 16 loops into 1 loop
#
# ```
# void AddDot4x4( int k, double *a, int lda,  double *b, int ldb, double *c, int ldc )
# {
#   /* So, this routine computes a 4x4 block of matrix A
#
#            C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 ).
#            C( 1, 0 ), C( 1, 1 ), C( 1, 2 ), C( 1, 3 ).
#            C( 2, 0 ), C( 2, 1 ), C( 2, 2 ), C( 2, 3 ).
#            C( 3, 0 ), C( 3, 1 ), C( 3, 2 ), C( 3, 3 ).
#
#      Notice that this routine is called with c = C( i, j ) in the
#      previous routine, so these are actually the elements
#
#            C( i  , j ), C( i  , j+1 ), C( i  , j+2 ), C( i  , j+3 )
#            C( i+1, j ), C( i+1, j+1 ), C( i+1, j+2 ), C( i+1, j+3 )
#            C( i+2, j ), C( i+2, j+1 ), C( i+2, j+2 ), C( i+2, j+3 )
#            C( i+3, j ), C( i+3, j+1 ), C( i+3, j+2 ), C( i+3, j+3 )
#
#      in the original matrix C
#
#      in this version, we merge each set of four loops, computing four
#      inner products simultaneously.
#
#      in this version, we accumulate in registers and put A( 0, p ) in a register
#      */
#
#     int p;
#
#     register double
#     /* hold contributions to
#        C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 )
#        C( 1, 0 ), C( 1, 1 ), C( 1, 2 ), C( 1, 3 )
#        C( 2, 0 ), C( 2, 1 ), C( 2, 2 ), C( 2, 3 )
#        C( 3, 0 ), C( 3, 1 ), C( 3, 2 ), C( 3, 3 )   */
#     c_00_reg,   c_01_reg,   c_02_reg,   c_03_reg,
#     c_10_reg,   c_11_reg,   c_12_reg,   c_13_reg,
#     c_20_reg,   c_21_reg,   c_22_reg,   c_23_reg,
#     c_30_reg,   c_31_reg,   c_32_reg,   c_33_reg,
#     /* hold
#        A( 0, p )
#        A( 1, p )
#        A( 2, p )
#        A( 3, p ) */
#     a_0p_reg,
#     a_1p_reg,
#     a_2p_reg,
#     a_3p_reg;
#
#     c_00_reg = 0.0;   c_01_reg = 0.0;   c_02_reg = 0.0;   c_03_reg = 0.0;
#     c_10_reg = 0.0;   c_11_reg = 0.0;   c_12_reg = 0.0;   c_13_reg = 0.0;
#     c_20_reg = 0.0;   c_21_reg = 0.0;   c_22_reg = 0.0;   c_23_reg = 0.0;
#     c_30_reg = 0.0;   c_31_reg = 0.0;   c_32_reg = 0.0;   c_33_reg = 0.0;
#
#     //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 0 ), &C( 0, 0 ) );
#     for ( p=0; p<k; p++ ){
#         a_0p_reg = A( 0, p );
#         a_1p_reg = A( 1, p );
#         a_2p_reg = A( 2, p );
#         a_3p_reg = A( 3, p );
#
#         /* First row */
#         c_00_reg += a_0p_reg * B( p, 0 );
#         c_01_reg += a_0p_reg * B( p, 1 );
#         c_02_reg += a_0p_reg * B( p, 2 );
#         c_03_reg += a_0p_reg * B( p, 3 );
#
#         /* Second row */
#         c_10_reg += a_1p_reg * B( p, 0 );
#         c_11_reg += a_1p_reg * B( p, 1 );
#         c_12_reg += a_1p_reg * B( p, 2 );
#         c_13_reg += a_1p_reg * B( p, 3 );
#
#         /* Third row */
#         c_20_reg += a_2p_reg * B( p, 0 );
#         c_21_reg += a_2p_reg * B( p, 1 );
#         c_22_reg += a_2p_reg * B( p, 2 );
#         c_23_reg += a_2p_reg * B( p, 3 );
#
#         /* Four row */
#         c_30_reg += a_3p_reg * B( p, 0 );
#         c_31_reg += a_3p_reg * B( p, 1 );
#         c_32_reg += a_3p_reg * B( p, 2 );
#         c_33_reg += a_3p_reg * B( p, 3 );
#     }
#
#     // update C(i,j) with value in register
#     C( 0, 0 ) += c_00_reg;   C( 0, 1 ) += c_01_reg;   C( 0, 2 ) += c_02_reg;   C( 0, 3 ) += c_03_reg;
#     C( 1, 0 ) += c_10_reg;   C( 1, 1 ) += c_11_reg;   C( 1, 2 ) += c_12_reg;   C( 1, 3 ) += c_13_reg;
#     C( 2, 0 ) += c_20_reg;   C( 2, 1 ) += c_21_reg;   C( 2, 2 ) += c_22_reg;   C( 2, 3 ) += c_23_reg;
#     C( 3, 0 ) += c_30_reg;   C( 3, 1 ) += c_31_reg;   C( 3, 2 ) += c_32_reg;   C( 3, 3 ) += c_33_reg;
# }
# ```

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_6 -DOUT=../data/MMult_4x4_6 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_6.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_6.c.o   -c /root/src/MMult_4x4_6.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_6.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    5.64 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   5.64 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_4.csv', f'{root_path}/data/MMult_4x4_5.csv',f'{root_path}/data/MMult_4x4_6.csv' ])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# We gain performance from both using register and blocking.
# * using register will improve performance for both small and big matrix
# * blocking mostly improve performance for big size matrix

# %% [markdown]
# ## MMult_4x4_7.c
#
# We use pointers to address elements in B
#
# ```
# void AddDot4x4( int k, double *a, int lda,  double *b, int ldb, double *c, int ldc )
# {
#   /* So, this routine computes a 4x4 block of matrix A
#
#            C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 ).
#            C( 1, 0 ), C( 1, 1 ), C( 1, 2 ), C( 1, 3 ).
#            C( 2, 0 ), C( 2, 1 ), C( 2, 2 ), C( 2, 3 ).
#            C( 3, 0 ), C( 3, 1 ), C( 3, 2 ), C( 3, 3 ).
#
#      Notice that this routine is called with c = C( i, j ) in the
#      previous routine, so these are actually the elements
#
#            C( i  , j ), C( i  , j+1 ), C( i  , j+2 ), C( i  , j+3 )
#            C( i+1, j ), C( i+1, j+1 ), C( i+1, j+2 ), C( i+1, j+3 )
#            C( i+2, j ), C( i+2, j+1 ), C( i+2, j+2 ), C( i+2, j+3 )
#            C( i+3, j ), C( i+3, j+1 ), C( i+3, j+2 ), C( i+3, j+3 )
#
#      in the original matrix C
#
#      in this version, we merge each set of four loops, computing four
#      inner products simultaneously.
#
#      in this version, we accumulate in registers and put A( 0, p ) in a register
#      */
#
#     int p;
#
#     register double
#     /* hold contributions to
#        C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 )
#        C( 1, 0 ), C( 1, 1 ), C( 1, 2 ), C( 1, 3 )
#        C( 2, 0 ), C( 2, 1 ), C( 2, 2 ), C( 2, 3 )
#        C( 3, 0 ), C( 3, 1 ), C( 3, 2 ), C( 3, 3 )   */
#     c_00_reg,   c_01_reg,   c_02_reg,   c_03_reg,
#     c_10_reg,   c_11_reg,   c_12_reg,   c_13_reg,
#     c_20_reg,   c_21_reg,   c_22_reg,   c_23_reg,
#     c_30_reg,   c_31_reg,   c_32_reg,   c_33_reg,
#     /* hold
#        A( 0, p )
#        A( 1, p )
#        A( 2, p )
#        A( 3, p ) */
#     a_0p_reg,
#     a_1p_reg,
#     a_2p_reg,
#     a_3p_reg;
#
#     c_00_reg = 0.0;   c_01_reg = 0.0;   c_02_reg = 0.0;   c_03_reg = 0.0;
#     c_10_reg = 0.0;   c_11_reg = 0.0;   c_12_reg = 0.0;   c_13_reg = 0.0;
#     c_20_reg = 0.0;   c_21_reg = 0.0;   c_22_reg = 0.0;   c_23_reg = 0.0;
#     c_30_reg = 0.0;   c_31_reg = 0.0;   c_32_reg = 0.0;   c_33_reg = 0.0;
#
#     //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 0 ), &C( 0, 0 ) );
#     for ( p=0; p<k; p++ ){
#         a_0p_reg = A( 0, p );
#         a_1p_reg = A( 1, p );
#         a_2p_reg = A( 2, p );
#         a_3p_reg = A( 3, p );
#
#         /* First row */
#         c_00_reg += a_0p_reg * B( p, 0 );
#         c_01_reg += a_0p_reg * B( p, 1 );
#         c_02_reg += a_0p_reg * B( p, 2 );
#         c_03_reg += a_0p_reg * B( p, 3 );
#
#         /* Second row */
#         c_10_reg += a_1p_reg * B( p, 0 );
#         c_11_reg += a_1p_reg * B( p, 1 );
#         c_12_reg += a_1p_reg * B( p, 2 );
#         c_13_reg += a_1p_reg * B( p, 3 );
#
#         /* Third row */
#         c_20_reg += a_2p_reg * B( p, 0 );
#         c_21_reg += a_2p_reg * B( p, 1 );
#         c_22_reg += a_2p_reg * B( p, 2 );
#         c_23_reg += a_2p_reg * B( p, 3 );
#
#         /* Four row */
#         c_30_reg += a_3p_reg * B( p, 0 );
#         c_31_reg += a_3p_reg * B( p, 1 );
#         c_32_reg += a_3p_reg * B( p, 2 );
#         c_33_reg += a_3p_reg * B( p, 3 );
#     }
#
#     // update C(i,j) with value in register
#     C( 0, 0 ) += c_00_reg;   C( 0, 1 ) += c_01_reg;   C( 0, 2 ) += c_02_reg;   C( 0, 3 ) += c_03_reg;
#     C( 1, 0 ) += c_10_reg;   C( 1, 1 ) += c_11_reg;   C( 1, 2 ) += c_12_reg;   C( 1, 3 ) += c_13_reg;
#     C( 2, 0 ) += c_20_reg;   C( 2, 1 ) += c_21_reg;   C( 2, 2 ) += c_22_reg;   C( 2, 3 ) += c_23_reg;
#     C( 3, 0 ) += c_30_reg;   C( 3, 1 ) += c_31_reg;   C( 3, 2 ) += c_32_reg;   C( 3, 3 ) += c_33_reg;
# }
# ```

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_7 -DOUT=../data/MMult_4x4_7 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_7.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_7.c.o   -c /root/src/MMult_4x4_7.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_7.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    5.65 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   5.65 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_5.csv', f'{root_path}/data/MMult_4x4_6.csv',f'{root_path}/data/MMult_1x4_7.csv', f'{root_path}/data/MMult_4x4_7.csv' ])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# * Compare with optimization 6, it is said that we reduced index overhead.
# * Compare with 1x4 block optimization 7, the performance is not improved. Both 1x4 and 4x4 blocking fusion gain almost same performance

# %% [markdown]
# ## Optimization 8
#
# We store a row of k x 4 matrix B in registers, i.e. use registers for elements in Matrix B.
# Because we unrolled as 4x4 block, so b_p0_reg will be also used 4 times in 1 loop.
#
# Part of code in MMult_4x4_8
# ```
#     ...
#     //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 0 ), &C( 0, 0 ) );
#     for ( p=0; p<k; p++ ){
#         a_0p_reg = A( 0, p );
#         a_1p_reg = A( 1, p );
#         a_2p_reg = A( 2, p );
#         a_3p_reg = A( 3, p );
#
#         b_p0_reg = *b_p0_pntr++;
#         b_p1_reg = *b_p1_pntr++;
#         b_p2_reg = *b_p2_pntr++;
#         b_p3_reg = *b_p3_pntr++;
#
#         /* First row */
#         c_00_reg += a_0p_reg * b_p0_reg;
#         c_01_reg += a_0p_reg * b_p1_reg;
#         c_02_reg += a_0p_reg * b_p2_reg;
#         c_03_reg += a_0p_reg * b_p3_reg;
#
#         /* Second row */
#         c_10_reg += a_1p_reg * b_p0_reg;
#         c_11_reg += a_1p_reg * b_p1_reg;
#         c_12_reg += a_1p_reg * b_p2_reg;
#         c_13_reg += a_1p_reg * b_p3_reg;
#
#         /* Third row */
#         c_20_reg += a_2p_reg * b_p0_reg;
#         c_21_reg += a_2p_reg * b_p1_reg;
#         c_22_reg += a_2p_reg * b_p2_reg;
#         c_23_reg += a_2p_reg * b_p3_reg;
#
#         /* Four row */
#         c_30_reg += a_3p_reg * b_p0_reg;
#         c_31_reg += a_3p_reg * b_p1_reg;
#         c_32_reg += a_3p_reg * b_p2_reg;
#         c_33_reg += a_3p_reg * b_p3_reg;
#     }
#     ...
# ```

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_8 -DOUT=../data/MMult_4x4_8 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_8.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_8.c.o   -c /root/src/MMult_4x4_8.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_8.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    5.61 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   5.61 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_7.csv', f'{root_path}/data/MMult_4x4_8.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# We did not gain on performance. We have the same situation for 1x4 block to use register on element in Matrix B.

# %% [markdown]
# ## Optimization 9
#
# We rearrange the computation so that two rows of 4x4 block of C are computed at a time. Instead of updating the rows of 4x4 block C a row at a time, we compute them two rows at a time.
# This sets us up for using vector operations, where we update pairs C( 0,j ) and C( 1,j ) (j =0,...,3) with vector operations.
# In brief, we just re-arrange the order of code. This re-arrangement will not give performance benefit
#
# The reason we combine first row and second row (just reorder) is to prepare to use vector operation in next optimization
#
# ```
#         /* First row and second row*/
#         c_00_reg += a_0p_reg * b_p0_reg;
#         c_10_reg += a_1p_reg * b_p0_reg;
#
#         c_01_reg += a_0p_reg * b_p1_reg;
#         c_11_reg += a_1p_reg * b_p1_reg;
#
#         c_02_reg += a_0p_reg * b_p2_reg;
#         c_12_reg += a_1p_reg * b_p2_reg;
#
#         c_03_reg += a_0p_reg * b_p3_reg;
#         c_13_reg += a_1p_reg * b_p3_reg;
#
#         /* Third row and fourth row*/
#         c_20_reg += a_2p_reg * b_p0_reg;
#         c_30_reg += a_3p_reg * b_p0_reg;
#
#         c_21_reg += a_2p_reg * b_p1_reg;
#         c_31_reg += a_3p_reg * b_p1_reg;
#
#         c_22_reg += a_2p_reg * b_p2_reg;
#         c_32_reg += a_3p_reg * b_p2_reg;
#
#         c_23_reg += a_2p_reg * b_p3_reg;
#         c_33_reg += a_3p_reg * b_p3_reg;
#
# ```

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_9 -DOUT=../data/MMult_4x4_9 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_9.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_9.c.o   -c /root/src/MMult_4x4_9.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_9.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    5.66 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   5.66 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_8.csv', f'{root_path}/data/MMult_4x4_9.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ## Optimization 10
#
# We use vector registers and vector operations.
# * First we need to include some new header files to use SSE, AVX intrinsic function
# * We also define a union which can hold the vector v (128 bit, for 2 double variable) or array d (length 2)
#
# ```
#
# #include <mmintrin.h>
# #include <xmmintrin.h>  // SSE
# #include <pmmintrin.h>  // SSE2
# #include <emmintrin.h>  // SSE3
#
# typedef union
# {
#   __m128d v;
#   double d[2];
# } v2df_t;
# ```
#
# We combine 2 elements in Matrix C, Matrix B and Matrix A into 1 vector during inner product calculation
#
# ```
#   v2df_t
#     c_00_c_10_vreg,    c_01_c_11_vreg,    c_02_c_12_vreg,    c_03_c_13_vreg,
#     c_20_c_30_vreg,    c_21_c_31_vreg,    c_22_c_32_vreg,    c_23_c_33_vreg,
#     a_0p_a_1p_vreg,
#     a_2p_a_3p_vreg,
#     b_p0_vreg, b_p1_vreg, b_p2_vreg, b_p3_vreg;
# ```
#
# * We use _mm_setzero_pd() to initialize the vector
# * We use _mm_load_pd to read 2 double data into vector for elements in C and A
# * For element in B, we use _mm_loaddup_pd to read 1 double data into v[0:63] and also duplicated it into v[64:127]
#
# ```
# for ( p=0; p<k; p++ ){
#     a_0p_a_1p_vreg.v = _mm_load_pd( (double *) &A( 0, p ) );
#     a_2p_a_3p_vreg.v = _mm_load_pd( (double *) &A( 2, p ) );
#
#     b_p0_vreg.v = _mm_loaddup_pd( (double *) b_p0_pntr++ );   /* load and duplicate */
#     b_p1_vreg.v = _mm_loaddup_pd( (double *) b_p1_pntr++ );   /* load and duplicate */
#     b_p2_vreg.v = _mm_loaddup_pd( (double *) b_p2_pntr++ );   /* load and duplicate */
#     b_p3_vreg.v = _mm_loaddup_pd( (double *) b_p3_pntr++ );   /* load and duplicate */
#
#     ...
# }
# ```
#
# For inner product calculate, we could see 4 statements correspond to 8 statements in optimization 9
#
# In MMult_4x4_9.c
# ```
#         /* First row and second row*/
#         c_00_reg += a_0p_reg * b_p0_reg;
#         c_10_reg += a_1p_reg * b_p0_reg;
#
#         c_01_reg += a_0p_reg * b_p1_reg;
#         c_11_reg += a_1p_reg * b_p1_reg;
#
#         c_02_reg += a_0p_reg * b_p2_reg;
#         c_12_reg += a_1p_reg * b_p2_reg;
#
#         c_03_reg += a_0p_reg * b_p3_reg;
#         c_13_reg += a_1p_reg * b_p3_reg;
#
# ```
#
# In MMult_4x4_10.c
# ```
#         /* First row and second row*/
#         c_00_c_10_vreg.v += a_0p_a_1p_vreg.v * b_p0_vreg.v;
#         c_01_c_11_vreg.v += a_0p_a_1p_vreg.v * b_p1_vreg.v;
#         c_02_c_12_vreg.v += a_0p_a_1p_vreg.v * b_p2_vreg.v;
#         c_03_c_13_vreg.v += a_0p_a_1p_vreg.v * b_p3_vreg.v;
# ```

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_10 -DOUT=../data/MMult_4x4_10 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_10.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_10.c.o   -c /root/src/MMult_4x4_10.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_10.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    5.38 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   5.38 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_9.csv', f'{root_path}/data/MMult_4x4_10.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# We get performance gain in both small and big matrix. We use vector operation to get benefit from SIMD (Single Instruction Multiple Data). In our case, 1 instruction to handle 2 data multiplication

# %% [markdown]
# ## Optimization 11
#
# In order to maintain the performance attained for smaller problem sizes, we block matrix C (and A and B correspondingly)
#
# ```
# /* We block the matrix C as mc x n, the matrix A as mc x kc, the matrix B as kc x nc */
# void MY_MMult( int m, int n, int k, double *a, int lda,
#                                     double *b, int ldb,
#                                     double *c, int ldc )
# {
#     int i, j, p, pb, ib;
#
#     /* This time, we compute a mc x n block of C by a call to the InnerKernel */
#     for ( p=0, p<k; p+=kc ) {
#         pb = min( k-p, kc ); // if left colums of Matrix B less than kc, then column of blocksize is k-p
#         for ( i=0, i<m; i+=mc) {
#             ib = min( m-i, mc ) // if left rows of Matrix A less than kc, then column of blocksize is m-i
#             InnerKernel (ib, n, pb, &A( i,p ), lda, &B(p, 0 ), ldb, &C( i,0 ), ldc );
#         }
#     }
# }
#
# /* This InnerKernel is old MY_MMult to calucate Matrix Multiplication with 4x4 blocking */
# void InnerKernel( int m, int n, int k, double *a, int lda,
#                                        double *b, int ldb,
#                                        double *c, int ldc )
# {
#   int i, j;
#
#   for ( j=0; j<n; j+=4 ){        /* Loop over the columns of C, unrolled by 4 */
#     for ( i=0; i<m; i+=4 ){        /* Loop over the rows of C */
#       /* Update C( i,j ), C( i,j+1 ), C( i,j+2 ), and C( i,j+3 ) in one routine (four inner products) */
#
#       AddDot4x4( k, &A( i,0 ), lda, &B( 0,j ), ldb, &C( i,j ), ldc );
#     }
#   }
# }
# ```
#
# This will give the performance gain.

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_11 -DOUT=../data/MMult_4x4_11 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_11.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_11.c.o   -c /root/src/MMult_4x4_11.c
# /root/src/MMult_4x4_11.c: In function ‘MY_MMult’:
# /root/src/MMult_4x4_11.c:24:12: warning: unused variable ‘j’ [-Wunused-variable]
#    24 |     int i, j, p, pb, ib;
#       |            ^
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_11.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    5.05 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   5.05 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_9.csv', f'{root_path}/data/MMult_4x4_10.csv', f'{root_path}/data/MMult_4x4_11.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# It is kind of superise me that blocking with size 256x128, will give extra performance gain
#
# From original result, it also show performance gain, specially on big matrix
#
# ![MMult_4x4_10 vs MMult_4x4_11](../figures/compare_MMult-4x4-10_MMult-4x4-11.png)
#
#
# Why we get the performance gain. The explaination could be
#
# The cache size is limited, when matrix size is bigger than L2 cache. No matter the matrix A and B is stored as column-major order or row-major order. The storage is not in continous in memory when we fetch 4x4 block.
# When we divide matrix into big block, this will save the cost for read data into L2 cache.
#
# So we do operation by 4x4 block, we benefit from fusing multiple loops into 1.
# Here we do operation first by 256x128 block to save cost of loading data into Cache.

# %% [markdown]
# ## Optimization 12 Packing into contiguous memory
#
# First, we pack the block of A so that we march through it contiguously.
#
# We save matrix A, the size is (m,k),  as column-major order. Then in optimization 11, we do blocking with size (mc=256, kc=128).
#
# To get a block, we
# * fetch 256 element from column 0.
# * jump to index of column 1. in our case, the index will be m*1. fetch 256 elements
# * jump to index of column 2, in our case, it is m*2. fetch 256 elements.
# * until we have fetch 128 columns
#
# Here we setup a PackMatrixA function. which go through the columns of A to pack k columns (in fact, it is kc columns), for each column, we fetch 4 elements and pack into the array packedA
# For each call to PackMatrixA, we will pack 4*k elements into packaedA from the index i*k. when inner i-loop finished, PackMatricsA will be called m/4 times and packedA will be filled with m*k (in fact, mc x kc) elements
#
# When calling AddDot4x4, we do not need to fetching data from original big Matrix A. Although we setup block mc x kc, the actual data is still saved in the big matrix array.
# Here, we extract block into small array packedA before AddDot.
#
# ```
# /* This InnerKernel is old MY_MMult to calucate Matrix Multiplication with 4x4 blocking */
# void InnerKernel( int m, int n, int k, double *a, int lda,
#                                        double *b, int ldb,
#                                        double *c, int ldc )
# {
#   int i, j;
#   double packedA[ m * k ];
#
#   for ( j=0; j<n; j+=4 ){        /* Loop over the columns of C, unrolled by 4 */
#     for ( i=0; i<m; i+=4 ){        /* Loop over the rows of C */
#       PackMatrixA( k, &A( i, 0 ), lda, &packedA[ i*k ] );
#       AddDot4x4( k, &packedA[ i*k ], 4, &B( 0,j ), ldb, &C( i,j ), ldc );
#     }
#   }
# }
#
#
# void PackMatrixA( int k, double *a, int lda, double *a_to )
# {
#   int j;
#
#   for( j=0; j<k; j++){  /* loop over columns of A */
#     double
#       *a_ij_pntr = &A( 0, j );
#
#     *a_to++ = *a_ij_pntr;
#     *a_to++ = *(a_ij_pntr+1);
#     *a_to++ = *(a_ij_pntr+2);
#     *a_to++ = *(a_ij_pntr+3);
#   }
# }
#
# ```

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_12 -DOUT=../data/MMult_4x4_12 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_12.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_12.c.o   -c /root/src/MMult_4x4_12.c
# /root/src/MMult_4x4_12.c: In function ‘MY_MMult’:
# /root/src/MMult_4x4_12.c:25:12: warning: unused variable ‘j’ [-Wunused-variable]
#    25 |     int i, j, p, pb, ib;
#       |            ^
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_12.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    5.68 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   5.68 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_10.csv', f'{root_path}/data/MMult_4x4_11.csv', f'{root_path}/data/MMult_4x4_12.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# Why we get the performance gain
#
# Look at the code of InnerKernel
# ```
# void InnerKernel( int m, int n, int k, double *a, int lda,
#                                        double *b, int ldb,
#                                        double *c, int ldc )
# {
#   int i, j;
#
#   for ( j=0; j<n; j+=4 ){        /* Loop over the columns of C, unrolled by 4 */
#     for ( i=0; i<m; i+=4 ){        /* Loop over the rows of C */
#       /* Update C( i,j ), C( i,j+1 ), C( i,j+2 ), and C( i,j+3 ) in one routine (four inner products) */
#
#       AddDot4x4( k, &A( i,0 ), lda, &B( 0,j ), ldb, &C( i,j ), ldc );
#     }
#   }
# }
# ```
#
# In the j,i loop, we need to access Matrix A many times. In brief, the potential gain of packing comes from
#
# * The ability to fit more data from A and B into the caches, which allows for bigger blocking and more data reuse
# * Contiguous, aligned, and predictable accesses, which minimize cache and data translation lookaside buffer (DTLB) misses
# * A reduction in loop overhead
#
# In general, the amount of time spent packing the input matrices is small, relative to the time spent in the computational kernel.
# However, for sizes where one of m or n is relatively small, as is common for some machine learning applications, the packing overhead can become significant.
#
# As a result, a GEMM implementation that does not rely on explicit packing can outperform a conventional, packing-based GEMM implementation, in brief, no packing GEMM out-perform packing GEMM in many deep learning cases.

# %% [markdown]
# ## Optimization 13
#
# Obviously, when j=0, 1, ... the packing process is same, we could reuse already packed array. So this version saves the packed blocks of A so that after the first iteration of the outer loop of InnerKernel, the saved version is used. The performance gain is noticeable! The only change from the last version is the addition of if ( j== 0 )
#
# ```
#       if ( j == 0 ) PackMatrixA( k, &A( i, 0 ), lda, &packedA[ i*k ] );
# ```

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_13 -DOUT=../data/MMult_4x4_13 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_13.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_13.c.o   -c /root/src/MMult_4x4_13.c
# /root/src/MMult_4x4_13.c: In function ‘MY_MMult’:
# /root/src/MMult_4x4_13.c:25:12: warning: unused variable ‘j’ [-Wunused-variable]
#    25 |     int i, j, p, pb, ib;
#       |            ^
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_13.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    4.84 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   4.84 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult0.csv',f'{root_path}/data/MMult_4x4_11.csv', f'{root_path}/data/MMult_4x4_12.csv', f'{root_path}/data/MMult_4x4_13.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# After reuse packedA, we get a large performance boost. The original figure shown as follow
#
# ![MMult_4x4_11 vs MMult_4x4_13](../figures/compare_MMult-4x4-11_MMult-4x4-13.png)

# %% [markdown]
# ## Optimization 14
#
# Finally, we pack the block of B so that we march through it contiguously. We do not need to explain why,
#
# We pack k*n  element into packedB.
# * For each call to function PackMatrixB, we fill kx4 elements into backedB.
# * We call PackMatrixB n/4 times, we finally fill n/4 x k x 4 = k x n elements into packedB
#
# ```
# /* This InnerKernel is old MY_MMult to calucate Matrix Multiplication with 4x4 blocking */
# void InnerKernel( int m, int n, int k, double *a, int lda,
#                                        double *b, int ldb,
#                                        double *c, int ldc )
# {
#   int i, j;
#   double packedA[ m * k ], packedB[ k*n ];
#
#   for ( j=0; j<n; j+=4 ){        /* Loop over the columns of C, unrolled by 4 */
#     PackMatrixB( k, &B( 0, j ), ldb, &packedB[ j*k ] );
#     for ( i=0; i<m; i+=4 ){        /* Loop over the rows of C */
#       /* Update C( i,j ), C( i,j+1 ), C( i,j+2 ), and C( i,j+3 ) in one routine (four inner products) */
#       if (j==0) PackMatrixA( k, &A( i, 0 ), lda, &packedA[ i*k ] );
#       AddDot4x4( k, &packedA[ i*k ], 4, &B( 0,j ), ldb, &C( i,j ), ldc );
#     }
#   }
# }
#
# void PackMatrixB( int k, double *b, int ldb, double *b_to )
# {
#   int i;
#   double
#     *b_i0_pntr = &B( 0, 0 ), *b_i1_pntr = &B( 0, 1 ),
#     *b_i2_pntr = &B( 0, 2 ), *b_i3_pntr = &B( 0, 3 );
#
#   for( i=0; i<k; i++){  /* loop over rows of B */
#     *b_to++ = *b_i0_pntr++;
#     *b_to++ = *b_i1_pntr++;
#     *b_to++ = *b_i2_pntr++;
#     *b_to++ = *b_i3_pntr++;
#   }
# }
# ```
#
# How we packed matrix B shown as following figure, note: in following figure m,n,k is defined same as m, n, k in InnerKernel.
#
# ![Pack Matrix B](../figures/PackMatrixB.jpg)
#
# if we consider for InnerKernel, we already blocked with mc, kc, when call InnerKernel, k should be kc. The actual storage shown as following
#
# ![Pack Matrix B (2)](../figures/PackMatrixB_2.jpg)

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_14 -DOUT=../data/MMult_4x4_14 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_4x4_14.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_4x4_14.c.o   -c /root/src/MMult_4x4_14.c
# /root/src/MMult_4x4_14.c: In function ‘MY_MMult’:
# /root/src/MMult_4x4_14.c:26:12: warning: unused variable ‘j’ [-Wunused-variable]
#    26 |     int i, j, p, pb, ib;
#       |            ^
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_4x4_14.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    4.58 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   4.58 sec

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_13.csv', f'{root_path}/data/MMult_4x4_14.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %%
## Optimization 15

We add some code that makes it so that we avoid repacking the kx4 blocks of B. Performance is now impressive!

* We define nb as 1000 for fixed length [kc x nb] for packedB
* We define packedB as static variable. 
    * A static variable is a variable that persists its value across the various function calls.
    * Using a static buffer is not thread safe
* We do PackMatrixB according to flag first_time. the first_time flag will be decided by i==0
    * We can see when InnerKernel is called with first_time = False, we do not do packMatrixB. 
    * Then we need to reuse packedB which is generated in previous function call. That is reason we need to use static buffer.
    * Of course we could use other ways to handle this problem. 


```
void MY_MMult( int m, int n, int k, double *a, int lda, 
                                    double *b, int ldb,
                                    double *c, int ldc )
{
  int i, p, pb, ib;

  /* This time, we compute a mc x n block of C by a call to the InnerKernel */

  for ( p=0; p<k; p+=kc ){
    pb = min( k-p, kc );
    for ( i=0; i<m; i+=mc ){
      ib = min( m-i, mc );
      InnerKernel( ib, n, pb, &A( i,p ), lda, &B(p, 0 ), ldb, &C( i,0 ), ldc, i==0 ); // i==0 is flag to indicate if we need PackMatrixB
    }
  }
}

/* This InnerKernel is old MY_MMult to calucate Matrix Multiplication with 4x4 blocking */
void InnerKernel( int m, int n, int k, double *a, int lda, 
                                       double *b, int ldb,
                                       double *c, int ldc, int first_time )
{
  int i, j;
  double packedA[ m * k ];
  static double packedB[ kc*nb ];  /* Note: using a static buffer is not thread safe... */

  for ( j=0; j<n; j+=4 ){        /* Loop over the columns of C, unrolled by 4 */
    if (first_time)
      PackMatrixB( k, &B( 0, j ), ldb, &packedB[ j*k ] );
    for ( i=0; i<m; i+=4 ){        /* Loop over the rows of C */
      /* Update C( i,j ), C( i,j+1 ), C( i,j+2 ), and C( i,j+3 ) in one routine (four inner products) */
      if (j==0) PackMatrixA( k, &A( i, 0 ), lda, &packedA[ i*k ] );
      AddDot4x4( k, &packedA[ i*k ], 4, &B( 0,j ), ldb, &C( i,j ), ldc );
    }
  }
}
```
# Out:
#   Cell In[32], line 3
#     We add some code that makes it so that we avoid repacking the kx4 blocks of B. Performance is now impressive!
#        ^
# SyntaxError: invalid syntax

# %%
# build and run the test
! cd $ROOT_PATH/build && cmake ../src -DNEW=MMult_4x4_15 -DOUT=../data/MMult_4x4_15 && make clean &&  make && make test

# %%
# import result and plot
data = load_data([f'{root_path}/data/MMult_4x4_13.csv', f'{root_path}/data/MMult_4x4_14.csv', f'{root_path}/data/MMult_4x4_15.csv'])
data.plot()

# %% [markdown]
# ### Result
#
# Slightly higher performance than optimization 14 for bigger matrix.
# Also, original wiki page claim "We now attain 90% of the turbo boost peak of the processor!"
#
# The original figure shown as following
#
# ![MMult_4x4_14 vs MMult_4x4_15](../figures/compare_MMult-4x4-14_MMult-4x4-15.png)

# %%
# import result and plot
# plot the final optimized implementation vs the first naive implementation 
data = load_data([f'{root_path}/data/MMult0.csv', f'{root_path}/data/MMult_4x4_15.csv'])
data.plot()
