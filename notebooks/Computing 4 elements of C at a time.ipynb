# %% [markdown]
# # Computing four elements of C at a time
#
# * We will compute 4 elements of matrix C at a time. i.e. 1x4 block
# * We will use register to improve performance

# %%
# load libs
from load_data import load_data

# %% [markdown]
# ## Optimization 1
#
# Change from MMult0.c to MMult1.c, we write AddDot function for dot-product. We will not gain performance by this rewriting
#
# ```
# /* Create macros so that the matrices are stored in column-major order */
#
# #define A(i,j) a[ (j)*lda + (i) ]
# #define B(i,j) b[ (j)*ldb + (i) ]
# #define C(i,j) c[ (j)*ldc + (i) ]
#
# /* Routine for computing C = A * B + C */
#
# void AddDot( int, double *, int, double *, double * );
#
# void MY_MMult( int m, int n, int k, double *a, int lda,
#                                     double *b, int ldb,
#                                     double *c, int ldc )
# {
#   int i, j;
#
#   for ( j=0; j<n; j+=1 ){        /* Loop over the columns of C */
#     for ( i=0; i<m; i+=1 ){        /* Loop over the rows of C */
#       /* Update the C( i,j ) with the inner product of the ith row of A
# 	 and the jth column of B */
#
#       AddDot( k, &A( i,0 ), lda, &B( 0,j ), &C( i,j ) );
#     }
#   }
# }
#
#
# /* Create macro to let X( i ) equal the ith element of x */
#
# #define X(i) x[ (i)*incx ]
#
# void AddDot( int k, double *x, int incx,  double *y, double *gamma )
# {
#   /* compute gamma := x' * y + gamma with vectors x and y of length n.
#
#      Here x starts at location x with increment (stride) incx and y starts at location y and has (implicit) stride of 1.
#   */
#
#   int p;
#
#   for ( p=0; p<k; p++ ){
#     *gamma += X( p ) * y[ p ];
#   }
# }
# ```

# %%
# build and run the test
! cd ../build && cmake ../src -DNEW=MMult1 -DOUT=../data/MMult1 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult1.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult1.c.o   -c /root/src/MMult1.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult1.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    9.88 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   9.88 sec

# %%
# import result and plot
data = load_data(['../data/MMult0.csv', '../data/MMult1.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ## Optimization 2
#
# We will do 4 elements of Matrix C update. But we call AddDot 4 times in MY_MMult. For each AddDot, there will be a for-loop.
# So, we in fact have 4 for-loops for 4 AddDot. Then we can not gain performance with SIMD.
#
# part of code in MMult2.c
# ```
# void MY_MMult( int m, int n, int k, double *a, int lda,
#                                     double *b, int ldb,
#                                     double *c, int ldc )
# {
#   int i, j;
#
#   for ( j=0; j<n; j+=4 ){        /* Loop over the columns of C, unrolled by 4 */
#     for ( i=0; i<m; i+=1 ){        /* Loop over the rows of C */
#       /* Update the C( i,j ) with the inner product of the ith row of A
# 	 and the jth column of B */
#
#       AddDot( k, &A( i,0 ), lda, &B( 0,j ), &C( i,j ) );
#
#       /* Update the C( i,j+1 ) with the inner product of the ith row of A
# 	 and the (j+1)th column of B */
#
#       AddDot( k, &A( i,0 ), lda, &B( 0,j+1 ), &C( i,j+1 ) );
#
#       /* Update the C( i,j+2 ) with the inner product of the ith row of A
# 	 and the (j+2)th column of B */
#
#       AddDot( k, &A( i,0 ), lda, &B( 0,j+2 ), &C( i,j+2 ) );
#
#       /* Update the C( i,j+3 ) with the inner product of the ith row of A
# 	 and the (j+1)th column of B */
#
#       AddDot( k, &A( i,0 ), lda, &B( 0,j+3 ), &C( i,j+3 ) );
#     }
#   }
# }
#
# ```

# %%
# build and run the test
! cd ../build && cmake ../src -DNEW=MMult2 -DOUT=../data/MMult2 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult2.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult2.c.o   -c /root/src/MMult2.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult2.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    9.29 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   9.29 sec

# %%
# import result and plot
data = load_data(['../data/MMult1.csv', '../data/MMult2.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# No performance gain by just calling 4 times AddDot in the loop

# %% [markdown]
# ## Optimization 3. AddDot 1x4
#
# Just setup a new function AddDot1x4, which call 4 times AddDot. Still, Each AddDot will have a for-looping, no blocking.
# No performance gain expected
#
# ```
# void AddDot1x4( int k, double *a, int lda,  double *b, int ldb, double *c, int ldc )
# {
#   /* So, this routine computes four elements of C:
#
#            C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 ).
#
#      Notice that this routine is called with c = C( i, j ) in the
#      previous routine, so these are actually the elements
#
#            C( i, j ), C( i, j+1 ), C( i, j+2 ), C( i, j+3 )
#
#      in the original matrix C */
#
#   AddDot( k, &A( 0, 0 ), lda, &B( 0, 0 ), &C( 0, 0 ) );
#   AddDot( k, &A( 0, 0 ), lda, &B( 0, 1 ), &C( 0, 1 ) );
#   AddDot( k, &A( 0, 0 ), lda, &B( 0, 2 ), &C( 0, 2 ) );
#   AddDot( k, &A( 0, 0 ), lda, &B( 0, 3 ), &C( 0, 3 ) );
# }
# ```

# %%
# build and run the test
! cd ../build && cmake ../src -DNEW=MMult_1x4_3 -DOUT=../data/MMult_1x4_3 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_1x4_3.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_1x4_3.c.o   -c /root/src/MMult_1x4_3.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_1x4_3.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    9.26 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   9.26 sec

# %%
# import result and plot
data = load_data(['../data/MMult2.csv', '../data/MMult_1x4_3.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ## Optimization 4 and 5
#
# Now we inline the four separate inner products and fuse the loops into one, thereby computing the four inner products simultaneously in one loop.
#
# * First, we inline the inner products into AddDot1x4 to get MMult_1x4_4.c. Only doing inline will not give performance gain.
# * Second, we fuse the 4 loops for inner products into one. This will give performance gain due to SIMD
#
# Part of code of MMult_1x4_4.c to inline code of AddDot into AddDot1x4
# ```
# void AddDot1x4( int k, double *a, int lda,  double *b, int ldb, double *c, int ldc )
# {
#   /* So, this routine computes four elements of C:
#
#            C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 ).
#
#      Notice that this routine is called with c = C( i, j ) in the
#      previous routine, so these are actually the elements
#
#            C( i, j ), C( i, j+1 ), C( i, j+2 ), C( i, j+3 )
#
#      in the original matrix C.
#
#      In this version, we "inline" AddDot */
#
#   int p;
#
#   //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 0 ), &C( 0, 0 ) );
#   for ( p=0; p<k; p++ ){
#     C( 0, 0 ) += A( 0, p ) * B( p, 0 );
#   }
#
#   //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 1 ), &C( 0, 1 ) );
#   for ( p=0; p<k; p++ ){
#     C( 0, 1 ) += A( 0, p ) * B( p, 1 );
#   }
#
#   //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 2 ), &C( 0, 2 ) );
#   for ( p=0; p<k; p++ ){
#     C( 0, 2 ) += A( 0, p ) * B( p, 2 );
#   }
#
#   //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 3 ), &C( 0, 3 ) );
#   for ( p=0; p<k; p++ ){
#     C( 0, 3 ) += A( 0, p ) * B( p, 3 );
#   }
# }
# ```
#
# Part of code of MMult_1x4_5.c to fuse 4 inner product into 1 for-loop.
# ```
# void AddDot1x4( int k, double *a, int lda,  double *b, int ldb, double *c, int ldc )
# {
#   /* So, this routine computes four elements of C:
#
#            C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 ).
#
#      Notice that this routine is called with c = C( i, j ) in the
#      previous routine, so these are actually the elements
#
#            C( i, j ), C( i, j+1 ), C( i, j+2 ), C( i, j+3 )
#
#      in the original matrix C.
#
#      In this version, we merge the four loops, computing four inner
#      products simultaneously. */
#
#   int p;
#
#   //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 0 ), &C( 0, 0 ) );
#   //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 1 ), &C( 0, 1 ) );
#   //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 2 ), &C( 0, 2 ) );
#   //  AddDot( k, &A( 0, 0 ), lda, &B( 0, 3 ), &C( 0, 3 ) );
#   for ( p=0; p<k; p++ ){
#     C( 0, 0 ) += A( 0, p ) * B( p, 0 );
#     C( 0, 1 ) += A( 0, p ) * B( p, 1 );
#     C( 0, 2 ) += A( 0, p ) * B( p, 2 );
#     C( 0, 3 ) += A( 0, p ) * B( p, 3 );
#   }
# }
# ```

# %%
# build and run the test
! cd ../build && cmake ../src -DNEW=MMult_1x4_4 -DOUT=../data/MMult_1x4_4 && make clean &&  make && make test
! cd ../build && cmake ../src -DNEW=MMult_1x4_5 -DOUT=../data/MMult_1x4_5 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_1x4_4.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_1x4_4.c.o   -c /root/src/MMult_1x4_4.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_1x4_4.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    9.20 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   9.20 sec
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_1x4_5.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_1x4_5.c.o   -c /root/src/MMult_1x4_5.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_1x4_5.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    9.03 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   9.03 sec

# %%
# import result and plot
data = load_data(['../data/MMult_1x4_3.csv', '../data/MMult_1x4_4.csv', '../data/MMult_1x4_5.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# As we expected, when we fuse 4 inner product into 1 for-loop, we will gain performance. in fact, it is blocking and gain performance due to SIMD
# MMult_1x4_5 has performance gain when matrix size bigger than 450

# %% [markdown]
# ## Optimization 6
#
# We accumulate the elements of C in registers and use a register for elements of A. Using register will also give the performance gain.
#
# * The element of Matrix C will be defined as register variable. in one AddDot, the variable will be reused K times
# * The element A(0, p) will be defined as register variable. in one for-loop, this variable will be reused 4 times.
# * We could expect the performance gain both on small and big matrix
#
# ```
# void AddDot1x4( int k, double *a, int lda,  double *b, int ldb, double *c, int ldc )
# {
#   /* So, this routine computes four elements of C:
#
#            C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 ).
#
#      Notice that this routine is called with c = C( i, j ) in the
#      previous routine, so these are actually the elements
#
#            C( i, j ), C( i, j+1 ), C( i, j+2 ), C( i, j+3 )
#
#      in the original matrix C.
#
#      In this version, we accumulate in registers and put A( 0, p ) in a register */
#
#   int p;
#   register double
#     /* hold contributions to
#        C( 0, 0 ), C( 0, 1 ), C( 0, 2 ), C( 0, 3 ) */
#        c_00_reg,   c_01_reg,   c_02_reg,   c_03_reg,
#     /* holds A( 0, p ) */
#        a_0p_reg;
#
#   c_00_reg = 0.0;
#   c_01_reg = 0.0;
#   c_02_reg = 0.0;
#   c_03_reg = 0.0;
#
#   for ( p=0; p<k; p++ ){
#     a_0p_reg = A( 0, p );
#
#     c_00_reg += a_0p_reg * B( p, 0 );
#     c_01_reg += a_0p_reg * B( p, 1 );
#     c_02_reg += a_0p_reg * B( p, 2 );
#     c_03_reg += a_0p_reg * B( p, 3 );
#   }
#
#   C( 0, 0 ) += c_00_reg;
#   C( 0, 1 ) += c_01_reg;
#   C( 0, 2 ) += c_02_reg;
#   C( 0, 3 ) += c_03_reg;
# }
# ```

# %%
# build and run the test
! cd ../build && cmake ../src -DNEW=MMult_1x4_6 -DOUT=../data/MMult_1x4_6 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_1x4_6.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_1x4_6.c.o   -c /root/src/MMult_1x4_6.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_1x4_6.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    5.96 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   5.96 sec

# %%
# import result and plot
data = load_data(['../data/MMult_1x4_4.csv', '../data/MMult_1x4_5.csv', '../data/MMult_1x4_6.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ## Optimization 7
#
# We use pointers to address elements in B
#
# ```
# ...
#   double
#     /* Point to the current elements in the four columns of B */
#     *bp0_pntr, *bp1_pntr, *bp2_pntr, *bp3_pntr;
#     bp0_pntr = &B( 0, 0 );
#     bp1_pntr = &B( 0, 1 );
#     bp2_pntr = &B( 0, 2 );
#     bp3_pntr = &B( 0, 3 );
# ...
#
#     for ( p=0; p<k; p++ ){
#         a_0p_reg = A( 0, p );
#
#         c_00_reg += a_0p_reg * *bp0_pntr++;
#         c_01_reg += a_0p_reg * *bp1_pntr++;
#         c_02_reg += a_0p_reg * *bp2_pntr++;
#         c_03_reg += a_0p_reg * *bp3_pntr++;
#       }
#
# ...
# ```

# %%
# build and run the test
! cd ../build && cmake ../src -DNEW=MMult_1x4_7 -DOUT=../data/MMult_1x4_7 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_1x4_7.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_1x4_7.c.o   -c /root/src/MMult_1x4_7.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_1x4_7.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    5.98 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   5.98 sec

# %%
# import result and plot
data = load_data(['../data/MMult_1x4_5.csv', '../data/MMult_1x4_6.csv', '../data/MMult_1x4_7.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# No performance gain by using pointer to trace element in B

# %% [markdown]
# ## Optimization 8
#
# We unroll the loop by four (a relatively arbitrary choice of unrolling factor).
# * In inner produt, in one loop, we update C(0,0), C(0,1), C(0,2), C(0,3)
# * But each element in C, e.g. C(0,0) we need to do k times update for inner product.
# * Here we calucate 4 columns of Matrix A, then we need k/4 loops, each loop we unroll it to do 4 times update
#
#
# ```
#     ...
#     /* Calculate 4 x 4 update in one loop */
#     for ( p=0; p<k; p+=4 ){
#         a_0p_reg = A( 0, p );
#
#         c_00_reg += a_0p_reg * *bp0_pntr++;
#         c_01_reg += a_0p_reg * *bp1_pntr++;
#         c_02_reg += a_0p_reg * *bp2_pntr++;
#         c_03_reg += a_0p_reg * *bp3_pntr++;
#
#         a_0p_reg = A( 0, p+1 );
#
#         c_00_reg += a_0p_reg * *bp0_pntr++;
#         c_01_reg += a_0p_reg * *bp1_pntr++;
#         c_02_reg += a_0p_reg * *bp2_pntr++;
#         c_03_reg += a_0p_reg * *bp3_pntr++;
#
#         a_0p_reg = A( 0, p+2 );
#
#         c_00_reg += a_0p_reg * *bp0_pntr++;
#         c_01_reg += a_0p_reg * *bp1_pntr++;
#         c_02_reg += a_0p_reg * *bp2_pntr++;
#         c_03_reg += a_0p_reg * *bp3_pntr++;
#
#         a_0p_reg = A( 0, p+3 );
#
#         c_00_reg += a_0p_reg * *bp0_pntr++;
#         c_01_reg += a_0p_reg * *bp1_pntr++;
#         c_02_reg += a_0p_reg * *bp2_pntr++;
#         c_03_reg += a_0p_reg * *bp3_pntr++;
#     }
# ```

# %%
# build and run the test
! cd ../build && cmake ../src -DNEW=MMult_1x4_8 -DOUT=../data/MMult_1x4_8 && make clean &&  make && make test
# Out:
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /root/build
# make -f CMakeFiles/Makefile2 clean
# make[1]: Entering directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/clean
# make[2]: Entering directory '/root/build'
# /usr/bin/cmake -P CMakeFiles/test_MMult.x.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/clean
# make[2]: Entering directory '/root/build'
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean.cmake
# make[2]: Leaving directory '/root/build'
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -S/root/src -B/root/build --check-build-system CMakeFiles/Makefile.cmake 0
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles /root/build/CMakeFiles/progress.marks
# make -f CMakeFiles/Makefile2 all
# make[1]: Entering directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src/utils /root/build /root/build/utils /root/build/utils/CMakeFiles/utils.dir/DependInfo.cmake --color=
# make[2]: Leaving directory '/root/build'
# make -f utils/CMakeFiles/utils.dir/build.make utils/CMakeFiles/utils.dir/build
# make[2]: Entering directory '/root/build'
# [ 10%] Building C object utils/CMakeFiles/utils.dir/REF_MMult.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/REF_MMult.c.o   -c /root/src/utils/REF_MMult.c
# [ 20%] Building C object utils/CMakeFiles/utils.dir/compare_matrices.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/compare_matrices.c.o   -c /root/src/utils/compare_matrices.c
# [ 30%] Building C object utils/CMakeFiles/utils.dir/copy_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/copy_matrix.c.o   -c /root/src/utils/copy_matrix.c
# [ 40%] Building C object utils/CMakeFiles/utils.dir/dclock.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/dclock.c.o   -c /root/src/utils/dclock.c
# [ 50%] Building C object utils/CMakeFiles/utils.dir/print_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/print_matrix.c.o   -c /root/src/utils/print_matrix.c
# [ 60%] Building C object utils/CMakeFiles/utils.dir/random_matrix.c.o
# cd /root/build/utils && gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/utils.dir/random_matrix.c.o   -c /root/src/utils/random_matrix.c
# [ 70%] Linking C static library libutils.a
# cd /root/build/utils && /usr/bin/cmake -P CMakeFiles/utils.dir/cmake_clean_target.cmake
# cd /root/build/utils && /usr/bin/cmake -E cmake_link_script CMakeFiles/utils.dir/link.txt --verbose=1
# /usr/bin/ar qc libutils.a  CMakeFiles/utils.dir/REF_MMult.c.o CMakeFiles/utils.dir/compare_matrices.c.o CMakeFiles/utils.dir/copy_matrix.c.o CMakeFiles/utils.dir/dclock.c.o CMakeFiles/utils.dir/print_matrix.c.o CMakeFiles/utils.dir/random_matrix.c.o
# /usr/bin/ranlib libutils.a
# make[2]: Leaving directory '/root/build'
# [ 70%] Built target utils
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/depend
# make[2]: Entering directory '/root/build'
# cd /root/build && /usr/bin/cmake -E cmake_depends "Unix Makefiles" /root/src /root/src /root/build /root/build /root/build/CMakeFiles/test_MMult.x.dir/DependInfo.cmake --color=
# Scanning dependencies of target test_MMult.x
# make[2]: Leaving directory '/root/build'
# make -f CMakeFiles/test_MMult.x.dir/build.make CMakeFiles/test_MMult.x.dir/build
# make[2]: Entering directory '/root/build'
# [ 80%] Building C object CMakeFiles/test_MMult.x.dir/test_MMult.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/test_MMult.c.o   -c /root/src/test_MMult.c
# [ 90%] Building C object CMakeFiles/test_MMult.x.dir/MMult_1x4_8.c.o
# gcc   -O2 -Wall -msse3 -lm   -std=gnu11 -o CMakeFiles/test_MMult.x.dir/MMult_1x4_8.c.o   -c /root/src/MMult_1x4_8.c
# [100%] Linking C executable test_MMult.x
# /usr/bin/cmake -E cmake_link_script CMakeFiles/test_MMult.x.dir/link.txt --verbose=1
# gcc  -O2 -Wall -msse3 -lm  -rdynamic CMakeFiles/test_MMult.x.dir/test_MMult.c.o CMakeFiles/test_MMult.x.dir/MMult_1x4_8.c.o  -o test_MMult.x  utils/libutils.a
# make[2]: Leaving directory '/root/build'
# [100%] Built target test_MMult.x
# make[1]: Leaving directory '/root/build'
# /usr/bin/cmake -E cmake_progress_start /root/build/CMakeFiles 0
# Running tests...
# /usr/bin/ctest --force-new-ctest-process
# Test project /root/build
#     Start 1: test_run
# 1/1 Test #1: test_run .........................   Passed    6.06 sec
#
# 100% tests passed, 0 tests failed out of 1
#
# Total Test time (real) =   6.06 sec

# %%
# import result and plot
data = load_data(['../data/MMult_1x4_7.csv', '../data/MMult_1x4_8.csv'])
data.plot()
# Out:
# <Axes: xlabel='p'>

# %% [markdown]
# ### Result
#
# No performance gain.

# %%
# build and run the test
! cd ../build && cmake ../src -DNEW=MMult_1x4_8 -DOUT=../data/MMult_1x4_8 && make clean &&  make && make test

# %%
# import result and plot
data = load_data(['../data/MMult_1x4_5.csv', '../data/MMult_1x4_6.csv', '../data/MMult_1x4_7.csv'])
data.plot()
